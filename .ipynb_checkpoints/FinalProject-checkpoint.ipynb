# %%
try:
    import urllib.request,urllib.parse,urllib.error
    import requests
    from bs4 import BeautifulSoup
    url = 'https://money.cnn.com/data/hotstocks/'
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page,'html.parser')
    table_MostActive = "wsod_dataTable wsod_dataTableBigAlt"
    data_MostActive = []
    tickersymbols = []
    temp = []
    tab = soup.find_all('table', attrs={'class':table_MostActive})[0]
    for row in tab.select('tr'):
        l1 = []
        for data in row.select('td'):
        
            l1.append(data.text)
        data_MostActive.append(l1)
    data_MostActive = data_MostActive[1:] #Slice the data_MostActive list from index 1 to to remove the null element present in the first index 
    #print(data_MostActive)

    for i in data_MostActive:
        tickersymbols = i[0].split(' ')[0]
        temp.append(tickersymbols)

    ticketurl = 'https://finance.yahoo.com/quote/{myticker}?p={myticker}&.tsrc=fin-srch-v1'

    proplist = []
    companylist = []

    for i in temp:
        mystockhandle = requests.get(ticketurl.format(myticker = i))
        soup = BeautifulSoup(mystockhandle.content,'html.parser')
        tab = soup.find_all('table',attrs={'class':['W(100%)']})[0]
        tab2 = soup.find_all('table',attrs={'class':['W(100%) M(0) Bdcl(c)']})[0]
        l1 = []
        for row in tab.select('tr'):
            for data in row.select('td'):
                l1.append(data.text)
        for row in tab2.select('tr'):
            for data in row.select('td'):
                l1.append(data.text)
                #print(l1)
        proplist.append(l1)
    
    neededprops = ['Open','Avg. Volume', 'PE Ratio (TTM)']
    props = []
    counto = 0
    print("Prop list:", proplist)
    for out in proplist:
        count = 0
        temp1 = []
    
        temp1.append(temp[counto])
        for s in out:
            if s in neededprops:
                temp1.append(proplist[counto][count+1])    
            count = count + 1
        props.append(temp1)
        counto = counto + 1
        print("Props:", props)
    for p in props:
        p[2] = p[2].replace(",","")
#         t = p[1]
#         p[1] = p[2]
#         p[2] = t
    print("Props v2:", props)
    import csv
    with open('stocks.txt', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(props)
except:
    print("Please provide valid URL, If provided the server might be down.")
# Out:
# Prop list: [['Previous Close', '10.45', 'Open', '10.53', 'Bid', '0.00 x 1000', 'Ask', '0.00 x 36100', "Day's Range", '10.34 - 10.56', '52 Week Range', '5.48 - 13.26', 'Volume', '108,624,543', 'Avg. Volume', '112,346,040', 'Market Cap', '91.979B', 'Beta (5Y Monthly)', '0.78', 'PE Ratio (TTM)', '29.83', 'EPS (TTM)', '0.35', 'Earnings Date', 'Jan 26, 2021', 'Forward Dividend & Yield', '0.04 (0.38%)', 'Ex-Dividend Date', 'Sep 25, 2020', '1y Target Est', '9.28'], ['Previous Close', '9.45', 'Open', '9.20', 'Bid', '0.00 x 40000', 'Ask', '0.00 x 45100', "Day's Range", '9.00 - 9.25', '52 Week Range', '3.96 - 9.57', 'Volume', '94,241,915', 'Avg. Volume', '64,902,566', 'Market Cap', '36.124B', 'Beta (5Y Monthly)', '1.23', 'PE Ratio (TTM)', 'N/A', 'EPS (TTM)', '-0.04', 'Earnings Date', 'Feb 02, 2021 - Feb 08, 2021', 'Forward Dividend & Yield', 'N/A (N/A)', 'Ex-Dividend Date', 'Jan 29, 2020', '1y Target Est', '8.98'], ['Previous Close', '20.23', 'Open', '20.48', 'Bid', '0.00 x 1800', 'Ask', '0.00 x 3100', "Day's Range", '19.92 - 20.90', '52 Week Range', '7.80 - 51.94', 'Volume', '59,346,157', 'Avg. Volume', '47,700,843', 'Market Cap', '22.798B', 'Beta (5Y Monthly)', '2.00', 'PE Ratio (TTM)', 'N/A', 'EPS (TTM)', '-10.60', 'Earnings Date', 'Dec 18, 2020 - Dec 22, 2020', 'Forward Dividend & Yield', 'N/A (N/A)', 'Ex-Dividend Date', 'Feb 20, 2020', '1y Target Est', '17.00'], ['Previous Close', '28.98', 'Open', '28.71', 'Bid', '0.00 x 36900', 'Ask', '0.00 x 900', "Day's Range", '28.48 - 29.04', '52 Week Range', '17.95 - 35.72', 'Volume', '54,912,077', 'Avg. Volume', '61,126,206', 'Market Cap', '251.132B', 'Beta (5Y Monthly)', '1.57', 'PE Ratio (TTM)', '14.30', 'EPS (TTM)', '2.03', 'Earnings Date', 'Jan 19, 2021', 'Forward Dividend & Yield', '0.72 (2.48%)', 'Ex-Dividend Date', 'Dec 03, 2020', '1y Target Est', '28.78'], ['Previous Close', '26.87', 'Open', '22.72', 'Bid', '21.66 x 1000', 'Ask', '21.70 x 3200', "Day's Range", '21.32 - 22.88', '52 Week Range', '5.26 - 26.99', 'Volume', '53,492,958', 'Avg. Volume', '9,890,149', 'Market Cap', '8.07B', 'Beta (5Y Monthly)', '1.63', 'PE Ratio (TTM)', 'N/A', 'EPS (TTM)', '-2.90', 'Earnings Date', 'Nov 24, 2020', 'Forward Dividend & Yield', 'N/A (N/A)', 'Ex-Dividend Date', 'Apr 06, 2021', '1y Target Est', '24.35'], ['Previous Close', '28.61', 'Open', '28.33', 'Bid', '0.00 x 36900', 'Ask', '0.00 x 1400', "Day's Range", '28.00 - 28.69', '52 Week Range', '20.76 - 54.75', 'Volume', '38,222,784', 'Avg. Volume', '42,098,395', 'Market Cap', '118.205B', 'Beta (5Y Monthly)', '1.09', 'PE Ratio (TTM)', '75.04', 'EPS (TTM)', '0.38', 'Earnings Date', 'Jan 15, 2021', 'Forward Dividend & Yield', '0.40 (1.40%)', 'Ex-Dividend Date', 'Nov 05, 2020', '1y Target Est', '30.14'], ['Previous Close', '22.55', 'Open', '22.83', 'Bid', '0.00 x 900', 'Ask', '0.00 x 1400', "Day's Range", '22.41 - 23.35', '52 Week Range', '7.03 - 59.78', 'Volume', '30,769,201', 'Avg. Volume', '27,739,707', 'Market Cap', '6.395B', 'Beta (5Y Monthly)', '2.75', 'PE Ratio (TTM)', 'N/A', 'EPS (TTM)', '-13.45', 'Earnings Date', 'Feb 18, 2021 - Feb 22, 2021', 'Forward Dividend & Yield', 'N/A (N/A)', 'Ex-Dividend Date', 'N/A', '1y Target Est', '20.15'], ['Previous Close', '16.78', 'Open', '16.65', 'Bid', '0.00 x 3200', 'Ask', '0.00 x 1800', "Day's Range", '15.94 - 17.09', '52 Week Range', '8.52 - 47.58', 'Volume', '29,364,480', 'Avg. Volume', '26,450,133', 'Market Cap', '15.57B', 'Beta (5Y Monthly)', '1.90', 'PE Ratio (TTM)', 'N/A', 'EPS (TTM)', '-17.28', 'Earnings Date', 'Feb 25, 2021 - Mar 01, 2021', 'Forward Dividend & Yield', '0.04 (0.24%)', 'Ex-Dividend Date', 'Dec 09, 2020', '1y Target Est', '12.73'], ['Previous Close', '57.06', 'Open', '56.27', 'Bid', '0.00 x 1000', 'Ask', '0.00 x 800', "Day's Range", '55.33 - 57.16', '52 Week Range', '32.00 - 83.11', 'Volume', '28,145,221', 'Avg. Volume', '26,956,827', 'Market Cap', '118.799B', 'Beta (5Y Monthly)', '1.81', 'PE Ratio (TTM)', '11.11', 'EPS (TTM)', '5.14', 'Earnings Date', 'Jan 15, 2021', 'Forward Dividend ...
